# %% [markdown]
# <a href="https://colab.research.google.com/github/nikamprachi750-cell/dataset_special_task/blob/main/Special_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files                          #uploaded csv file
import pandas as pd

uploaded = files.upload()

df = pd.read_csv("heart[1].csv")  # Replace with your actual file name

print(df.head())
# Out:
#      <input type="file" id="files-0eb1999c-f882-44b4-a0db-62c55ce7f69e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0eb1999c-f882-44b4-a0db-62c55ce7f69e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df                                                    #Prints whole dataset
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.tail()                                 #displays last 5 rows of dataframe
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0

# %%
df.shape                                #Returns rows and columns as tuple
# Out:
# (918, 12)

# %%
df.info()                                 #prints column name,datatypes and non null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.columns                            #prints all column names
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
df.dtypes                                   #prints the datatype of each column
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %%
df.describe()                             #gives summary statistics for numeric columns
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.isnull().sum()                       #counts missing values per column
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.nunique()                                  #Counts unique values per column
# Out:
# Age                50
# Sex                 2
# ChestPainType       4
# RestingBP          67
# Cholesterol       222
# FastingBS           2
# RestingECG          3
# MaxHR             119
# ExerciseAngina      2
# Oldpeak            53
# ST_Slope            3
# HeartDisease        2
# dtype: int64

# %%
df['Cholesterol']                             #Prints the single column
# Out:
# 0      289
# 1      180
# 2      283
# 3      214
# 4      195
#       ...
# 913    264
# 914    193
# 915    131
# 916    236
# 917    175
# Name: Cholesterol, Length: 918, dtype: int64

# %%
df.loc[0,'ChestPainType']                           #selects rows/columns by labels
# Out:
# 'ATA'

# %%
df.iloc[0:5,0:3]
# Out:
#    Age Sex ChestPainType
# 0   40   M           ATA
# 1   49   F           NAP
# 2   37   M           ATA
# 3   48   F           ASY
# 4   54   M           NAP

# %%
df.at[0,'ChestPainType']                          #fast access to a single value by label
# Out:
# 'ATA'

# %%
df.sort_values('Age')                                 #sort rows by one or more columns
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 208   28   M           ATA        130          132          0        LVH
# 829   29   M           ATA        130          204          0        LVH
# 170   29   M           ATA        120          243          0     Normal
# 219   29   M           ATA        140          263          0     Normal
# 215   30   F            TA        170          237          0         ST
# ..   ...  ..           ...        ...          ...        ...        ...
# 556   75   M           ASY        160          310          1     Normal
# 688   76   F           NAP        140          197          0         ST
# 541   76   M           NAP        104          113          0        LVH
# 814   77   M           ASY        125          304          0        LVH
# 447   77   M           ASY        124          171          0         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.groupby('Cholesterol')['MaxHR'].sum()        #Groups rows by a column for aggregation
# Out:
# Cholesterol
# 0      20982
# 85       140
# 100      258
# 110      109
# 113      120
#        ...
# 491      135
# 518      130
# 529      130
# 564      160
# 603      125
# Name: MaxHR, Length: 222, dtype: int64

# %%
df['RestingECG'].value_counts()                       #Counts Occurence of each unique value
# Out:
# RestingECG
# Normal    552
# LVH       188
# ST        178
# Name: count, dtype: int64

# %%
df['Cholesterol'].mean()                        #calculates average values of a column
# Out:
# np.float64(198.7995642701525)

# %%
df['Cholesterol'].median()                        #calculates middle value of a column
# Out:
# 223.0

# %%
df['RestingBP'].max()                           #Prints maximum value in column
# Out:
# 200

# %%
df['RestingBP'].sum()                             #adds up all values in a column
# Out:
# np.int64(121540)

# %%
df['RestingBP'].fillna(0)                               #Replaes missing values with a given values
# Out:
# 0      140
# 1      160
# 2      130
# 3      138
# 4      150
#       ...
# 913    110
# 914    144
# 915    130
# 916    130
# 917    138
# Name: RestingBP, Length: 918, dtype: int64

# %%
df.drop(columns=['Oldpeak'])                                #removes specified row or column
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina ST_Slope  HeartDisease
# ...
